# %%
import torch
import pandas as pd
import numpy as np
import os
import optuna
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error, recall_score
from sklearn import svm

# %%
def f1(y_true, y_pred):
    return round(f1_score(y_true, y_pred, average='micro') * 100, 3)


def uar(y_true, y_pred):
    return round(recall_score(y_true, y_pred, average='macro') * 100, 3)

def combine(y_true, y_pred):
    return round((0.66 * f1(y_true, y_pred) + 0.34 * uar(y_true, y_pred)), 3)

def eval_metric(targets,predicts, partition_name):
    results = {}
    results['f1'] = f1(targets, predicts)
    results['uar'] = uar(targets, predicts)
    results['combine'] = combine(targets, predicts)
    print(f'Results in {partition_name}:')
    print("  - f1: ", results['f1'])
    print("  - uar: ", results['uar'])
    print("  - combined:", results['combine'])

# %%
def dataset(partition, feature_set):
    train = pd.read_csv(os.path.join('./data_csv/',partition,feature_set+'_train.csv'))
    valid = pd.read_csv(os.path.join('./data_csv/',partition,feature_set+'_devel.csv'))
    return train, valid

# %%
import lightgbm as lgb
# FYI: Objective functions can take additional arguments
# (https://optuna.readthedocs.io/en/stable/faq.html#objective-func-additional-args).
def lightgbm(trial):
    X_train, y_train = train.loc[:,'segment_id':'{}'.format(last_columns)], train['class_id']
    X_valid, y_valid = valid.loc[:,'segment_id':'{}'.format(last_columns)], valid['class_id']
    dtrain = lgb.Dataset(X_train, label=y_train)

    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
        "lambda_l2": trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_uniform("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_uniform("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    gbm = lgb.train(param, dtrain)
    preds = gbm.predict(X_valid)
    pred_labels = np.rint(preds)
    accuracy = combine(y_valid, pred_labels)
    return accuracy

# %%
maps = {
         'vggface': 512,
        }

for partition in ['arousal','valence']:
    for feature_set, num_columns in maps.items():
        train, valid = dataset(partition, feature_set)
        last_columns = num_columns - 1 
        study = optuna.create_study(direction='maximize')
        study.optimize(lightgbm, n_trials=1000)

        trial = study.best_trial
        print('Accuracy: {}'.format(trial.value))
        print('Parameter: {}'.format(trial.params))
        
        df = pd.DataFrame([[partition, feature_set, trial.value, trial.params]], columns=['patition', 'feature_set', 'value', 'params'])
        if not os.path.exists('./optimize'):
            os.makedirs('./optimize')
        if os.path.exists('./optimize/optimize_{}.csv'.format(feature_set)):
            df2 = pd.read_csv('./optimize/optimize_{}.csv'.format(feature_set))
            df2 = df2.append(df, ignore_index = True)
            df2.to_csv('./optimize/optimize_{}.csv'.format(feature_set), index=False)
        else:
            df.to_csv('./optimize/optimize_{}.csv'.format(feature_set), index=False)
# Out:
# [I 2020-07-15 10:40:46,794] Finished trial#0 with value: 39.216 with parameters: {'lambda_l1': 9.411364326571016, 'lambda_l2': 0.0001302234865937086, 'num_leaves': 15, 'feature_fraction': 0.6901804811998362, 'bagging_fraction': 0.9247905090826531, 'bagging_freq': 6, 'min_child_samples': 57}. Best is trial#0 with value: 39.216.
# [I 2020-07-15 10:40:48,271] Finished trial#1 with value: 38.785 with parameters: {'lambda_l1': 0.003616210692393305, 'lambda_l2': 0.009710984839007638, 'num_leaves': 125, 'feature_fraction': 0.7795187076726453, 'bagging_fraction': 0.5843855314700953, 'bagging_freq': 1, 'min_child_samples': 51}. Best is trial#0 with value: 39.216.
# [I 2020-07-15 10:40:48,815] Finished trial#2 with value: 39.972 with parameters: {'lambda_l1': 0.10360987161072097, 'lambda_l2': 0.3861073492589465, 'num_leaves': 11, 'feature_fraction': 0.5121455623198519, 'bagging_fraction': 0.7236754791798101, 'bagging_freq': 1, 'min_child_samples': 97}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:40:50,205] Finished trial#3 with value: 38.569 with parameters: {'lambda_l1': 2.3151153892903705e-07, 'lambda_l2': 0.06982850287833474, 'num_leaves': 230, 'feature_fraction': 0.7562480770541231, 'bagging_fraction': 0.6532251387148602, 'bagging_freq': 5, 'min_child_samples': 63}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:40:51,454] Finished trial#4 with value: 39.749 with parameters: {'lambda_l1': 0.008242848685389964, 'lambda_l2': 0.014917149520798529, 'num_leaves': 33, 'feature_fraction': 0.5753976828373598, 'bagging_fraction': 0.8215131751883475, 'bagging_freq': 7, 'min_child_samples': 50}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:40:55,563] Finished trial#5 with value: 38.809 with parameters: {'lambda_l1': 0.0030535711249405602, 'lambda_l2': 0.0005290732994866908, 'num_leaves': 207, 'feature_fraction': 0.7616418518388042, 'bagging_fraction': 0.7346449448155111, 'bagging_freq': 6, 'min_child_samples': 19}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:40:57,014] Finished trial#6 with value: 37.887 with parameters: {'lambda_l1': 7.899227617714448e-06, 'lambda_l2': 2.59817569364882e-05, 'num_leaves': 41, 'feature_fraction': 0.6165165687685394, 'bagging_fraction': 0.8684794947151121, 'bagging_freq': 7, 'min_child_samples': 60}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:40:59,646] Finished trial#7 with value: 39.108 with parameters: {'lambda_l1': 2.576753710228452e-08, 'lambda_l2': 0.00018892394459336421, 'num_leaves': 111, 'feature_fraction': 0.8845072956457654, 'bagging_fraction': 0.9429882659624084, 'bagging_freq': 7, 'min_child_samples': 51}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:08,996] Finished trial#8 with value: 38.148 with parameters: {'lambda_l1': 0.00014646833163250384, 'lambda_l2': 0.0035481112351856015, 'num_leaves': 165, 'feature_fraction': 0.9709020600608447, 'bagging_fraction': 0.9917166565019913, 'bagging_freq': 1, 'min_child_samples': 10}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:10,422] Finished trial#9 with value: 38.614 with parameters: {'lambda_l1': 0.0002918173799253519, 'lambda_l2': 0.13294206107275475, 'num_leaves': 42, 'feature_fraction': 0.7407850546843637, 'bagging_fraction': 0.5215238619360115, 'bagging_freq': 1, 'min_child_samples': 46}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:10,828] Finished trial#10 with value: 38.851 with parameters: {'lambda_l1': 2.6810563785777677, 'lambda_l2': 1.7588817845731174e-08, 'num_leaves': 85, 'feature_fraction': 0.4054829261005936, 'bagging_fraction': 0.40724568032086883, 'bagging_freq': 3, 'min_child_samples': 100}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:11,055] Finished trial#11 with value: 38.521 with parameters: {'lambda_l1': 0.19849572483356076, 'lambda_l2': 9.873091514787902, 'num_leaves': 2, 'feature_fraction': 0.48382794000546137, 'bagging_fraction': 0.7997062333773901, 'bagging_freq': 3, 'min_child_samples': 100}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:12,064] Finished trial#12 with value: 38.494 with parameters: {'lambda_l1': 0.10087748559947483, 'lambda_l2': 4.5161315131121285, 'num_leaves': 69, 'feature_fraction': 0.5358780289927206, 'bagging_fraction': 0.7839455276272852, 'bagging_freq': 3, 'min_child_samples': 79}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:12,319] Finished trial#13 with value: 39.101 with parameters: {'lambda_l1': 0.08487549794650363, 'lambda_l2': 0.6220656429880985, 'num_leaves': 3, 'feature_fraction': 0.40146518958717814, 'bagging_fraction': 0.6641333545248815, 'bagging_freq': 4, 'min_child_samples': 34}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:13,426] Finished trial#14 with value: 38.485 with parameters: {'lambda_l1': 0.00817424292241966, 'lambda_l2': 4.3493220952819275e-06, 'num_leaves': 54, 'feature_fraction': 0.5757837942319679, 'bagging_fraction': 0.857611057687635, 'bagging_freq': 2, 'min_child_samples': 82}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:14,093] Finished trial#15 with value: 39.667 with parameters: {'lambda_l1': 0.8543989860145188, 'lambda_l2': 1.3125863711353087, 'num_leaves': 19, 'feature_fraction': 0.46551100545590185, 'bagging_fraction': 0.7137760775508895, 'bagging_freq': 5, 'min_child_samples': 77}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:15,959] Finished trial#16 with value: 37.122 with parameters: {'lambda_l1': 1.228635648041228e-05, 'lambda_l2': 0.012997394941246163, 'num_leaves': 166, 'feature_fraction': 0.6424181634340507, 'bagging_fraction': 0.576624744670002, 'bagging_freq': 2, 'min_child_samples': 30}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:17,790] Finished trial#17 with value: 37.689 with parameters: {'lambda_l1': 0.008464192459720193, 'lambda_l2': 3.5659998008636865e-07, 'num_leaves': 91, 'feature_fraction': 0.5542400095797363, 'bagging_fraction': 0.8055974745464867, 'bagging_freq': 5, 'min_child_samples': 38}. Best is trial#2 with value: 39.972.
# [I 2020-07-15 10:41:18,794] Finished trial#18 with value: 39.974 with parameters: {'lambda_l1': 0.0323153763229321, 'lambda_l2': 0.10940467219679716, 'num_leaves': 33, 'feature_fraction': 0.4708708422673554, 'bagging_fraction': 0.8707267684850867, 'bagging_freq': 6, 'min_child_samples': 70}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:19,447] Finished trial#19 with value: 39.234 with parameters: {'lambda_l1': 8.331165327164982, 'lambda_l2': 0.2533561146780872, 'num_leaves': 153, 'feature_fraction': 0.4684576532179906, 'bagging_fraction': 0.9957710917057339, 'bagging_freq': 6, 'min_child_samples': 90}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:20,398] Finished trial#20 with value: 39.096 with parameters: {'lambda_l1': 0.6167550970144179, 'lambda_l2': 3.0651470314257603, 'num_leaves': 73, 'feature_fraction': 0.4003455268505144, 'bagging_fraction': 0.899735735249037, 'bagging_freq': 4, 'min_child_samples': 68}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:21,282] Finished trial#21 with value: 39.081 with parameters: {'lambda_l1': 0.012849099420834826, 'lambda_l2': 0.02420223622380742, 'num_leaves': 33, 'feature_fraction': 0.47097967083837483, 'bagging_fraction': 0.7683008572671618, 'bagging_freq': 7, 'min_child_samples': 88}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:22,272] Finished trial#22 with value: 39.676 with parameters: {'lambda_l1': 0.048177596604960314, 'lambda_l2': 0.002981360378278714, 'num_leaves': 22, 'feature_fraction': 0.5150630703631964, 'bagging_fraction': 0.8487919079462904, 'bagging_freq': 6, 'min_child_samples': 67}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:23,880] Finished trial#23 with value: 39.116 with parameters: {'lambda_l1': 0.001641747870639923, 'lambda_l2': 0.08660488170435504, 'num_leaves': 55, 'feature_fraction': 0.6244375879930383, 'bagging_fraction': 0.6904995251171983, 'bagging_freq': 7, 'min_child_samples': 42}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:24,254] Finished trial#24 with value: 38.952 with parameters: {'lambda_l1': 0.029079110681409327, 'lambda_l2': 0.0011908034039760293, 'num_leaves': 5, 'feature_fraction': 0.5877134268988019, 'bagging_fraction': 0.8331818205822702, 'bagging_freq': 5, 'min_child_samples': 72}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:24,982] Finished trial#25 with value: 38.722 with parameters: {'lambda_l1': 0.0005484736648060474, 'lambda_l2': 0.5472118675787353, 'num_leaves': 101, 'feature_fraction': 0.4363283468830398, 'bagging_fraction': 0.7522474452709037, 'bagging_freq': 6, 'min_child_samples': 92}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:26,957] Finished trial#26 with value: 38.034 with parameters: {'lambda_l1': 0.39350581646056054, 'lambda_l2': 0.04292956679301008, 'num_leaves': 59, 'feature_fraction': 0.665241712944934, 'bagging_fraction': 0.959046047722939, 'bagging_freq': 7, 'min_child_samples': 55}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:27,202] Finished trial#27 with value: 37.853 with parameters: {'lambda_l1': 3.4744423952764704e-05, 'lambda_l2': 0.005321686837362548, 'num_leaves': 2, 'feature_fraction': 0.5249854694967686, 'bagging_fraction': 0.9035658862092747, 'bagging_freq': 2, 'min_child_samples': 26}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:28,044] Finished trial#28 with value: 38.71 with parameters: {'lambda_l1': 1.9620504474735285, 'lambda_l2': 1.5969507047141036, 'num_leaves': 33, 'feature_fraction': 0.5007932729807547, 'bagging_fraction': 0.6278623116910536, 'bagging_freq': 6, 'min_child_samples': 46}. Best is trial#18 with value: 39.974.
# [I 2020-07-15 10:41:29,063] Finished trial#29 with value: 40.121 with parameters: {'lambda_l1': 0.0007733643804358296, 'lambda_l2': 6.1032448120766156e-05, 'num_leaves': 19, 'feature_fraction': 0.7005192503820518, 'bagging_fraction': 0.9035761657845851, 'bagging_freq': 6, 'min_child_samples': 58}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:30,172] Finished trial#30 with value: 40.121 with parameters: {'lambda_l1': 0.0010245219579119692, 'lambda_l2': 3.2673178258221556e-05, 'num_leaves': 18, 'feature_fraction': 0.8257391009955135, 'bagging_fraction': 0.9016261227068201, 'bagging_freq': 4, 'min_child_samples': 74}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:31,203] Finished trial#31 with value: 39.672 with parameters: {'lambda_l1': 0.0007516765700838366, 'lambda_l2': 2.9434972699161556e-05, 'num_leaves': 16, 'feature_fraction': 0.8299432881322043, 'bagging_fraction': 0.9163954974324808, 'bagging_freq': 4, 'min_child_samples': 75}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:32,416] Finished trial#32 with value: 39.374 with parameters: {'lambda_l1': 7.47249088066846e-05, 'lambda_l2': 1.5001815254136569e-06, 'num_leaves': 19, 'feature_fraction': 0.8610411143839024, 'bagging_fraction': 0.9619626112595923, 'bagging_freq': 5, 'min_child_samples': 85}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:32,733] Finished trial#33 with value: 39.096 with parameters: {'lambda_l1': 0.0015947572302427162, 'lambda_l2': 2.0982075542002893e-05, 'num_leaves': 3, 'feature_fraction': 0.7155598788429428, 'bagging_fraction': 0.8986040974804056, 'bagging_freq': 5, 'min_child_samples': 59}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:34,665] Finished trial#34 with value: 38.492 with parameters: {'lambda_l1': 2.307422762159286e-06, 'lambda_l2': 5.692233281338092e-06, 'num_leaves': 48, 'feature_fraction': 0.8013562814557909, 'bagging_fraction': 0.8787613736830416, 'bagging_freq': 3, 'min_child_samples': 69}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:36,308] Finished trial#35 with value: 39.3 with parameters: {'lambda_l1': 0.03119102036387617, 'lambda_l2': 8.840194519883636e-05, 'num_leaves': 25, 'feature_fraction': 0.965940196758159, 'bagging_fraction': 0.9937237737703674, 'bagging_freq': 6, 'min_child_samples': 94}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:38,891] Finished trial#36 with value: 38.803 with parameters: {'lambda_l1': 0.004320667931949956, 'lambda_l2': 0.0005970808220184755, 'num_leaves': 73, 'feature_fraction': 0.9010722231315323, 'bagging_fraction': 0.943073700546749, 'bagging_freq': 4, 'min_child_samples': 63}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:40,395] Finished trial#37 with value: 38.947 with parameters: {'lambda_l1': 0.0011976132812713683, 'lambda_l2': 6.889968294356295e-05, 'num_leaves': 38, 'feature_fraction': 0.6924603144975595, 'bagging_fraction': 0.8292538449863185, 'bagging_freq': 5, 'min_child_samples': 64}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:41,739] Finished trial#38 with value: 39.672 with parameters: {'lambda_l1': 0.0001635173781813965, 'lambda_l2': 2.538869406363278e-07, 'num_leaves': 252, 'feature_fraction': 0.9305387531928381, 'bagging_fraction': 0.4808531314522436, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:43,176] Finished trial#39 with value: 38.785 with parameters: {'lambda_l1': 0.016843389856439933, 'lambda_l2': 0.00026528172479405623, 'num_leaves': 135, 'feature_fraction': 0.7989184747709162, 'bagging_fraction': 0.7373672701069716, 'bagging_freq': 1, 'min_child_samples': 76}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:44,837] Finished trial#40 with value: 38.651 with parameters: {'lambda_l1': 0.1909259465105905, 'lambda_l2': 0.0013488062649364056, 'num_leaves': 204, 'feature_fraction': 0.734002916117673, 'bagging_fraction': 0.9380911747735247, 'bagging_freq': 2, 'min_child_samples': 83}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:46,155] Finished trial#41 with value: 39.157 with parameters: {'lambda_l1': 0.002136667863449781, 'lambda_l2': 0.022001061854373876, 'num_leaves': 31, 'feature_fraction': 0.5864001704010801, 'bagging_fraction': 0.8188169763614642, 'bagging_freq': 7, 'min_child_samples': 60}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:46,648] Finished trial#42 with value: 39.38 with parameters: {'lambda_l1': 0.005147980498660907, 'lambda_l2': 0.26696729673115066, 'num_leaves': 11, 'feature_fraction': 0.4266201886734882, 'bagging_fraction': 0.8723848000397135, 'bagging_freq': 7, 'min_child_samples': 46}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:48,056] Finished trial#43 with value: 38.643 with parameters: {'lambda_l1': 0.00015374872541662813, 'lambda_l2': 1.0975101448492852e-05, 'num_leaves': 44, 'feature_fraction': 0.5522282462654587, 'bagging_fraction': 0.8512723138449702, 'bagging_freq': 6, 'min_child_samples': 52}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:49,806] Finished trial#44 with value: 38.433 with parameters: {'lambda_l1': 0.00032012666781081116, 'lambda_l2': 0.00017122670218499073, 'num_leaves': 60, 'feature_fraction': 0.666543214927107, 'bagging_fraction': 0.7870652901826689, 'bagging_freq': 7, 'min_child_samples': 50}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:50,504] Finished trial#45 with value: 40.04 with parameters: {'lambda_l1': 0.07165725775310744, 'lambda_l2': 0.13005803476702713, 'num_leaves': 13, 'feature_fraction': 0.6105177869302003, 'bagging_fraction': 0.7099515922750019, 'bagging_freq': 6, 'min_child_samples': 64}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:50,941] Finished trial#46 with value: 39.749 with parameters: {'lambda_l1': 0.16730021771757295, 'lambda_l2': 1.9230846026355065e-06, 'num_leaves': 8, 'feature_fraction': 0.43881914970946373, 'bagging_fraction': 0.6272067971682141, 'bagging_freq': 6, 'min_child_samples': 96}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:51,827] Finished trial#47 with value: 38.66 with parameters: {'lambda_l1': 7.567574504451813, 'lambda_l2': 0.1288961132846375, 'num_leaves': 28, 'feature_fraction': 0.6205329464836891, 'bagging_fraction': 0.6832552758287449, 'bagging_freq': 5, 'min_child_samples': 71}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:52,572] Finished trial#48 with value: 39.437 with parameters: {'lambda_l1': 0.06114360422470144, 'lambda_l2': 7.196215958430049, 'num_leaves': 14, 'feature_fraction': 0.6544205182150176, 'bagging_fraction': 0.5826822517828217, 'bagging_freq': 3, 'min_child_samples': 65}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:53,827] Finished trial#49 with value: 39.092 with parameters: {'lambda_l1': 1.367458362359338, 'lambda_l2': 0.5643699228766283, 'num_leaves': 46, 'feature_fraction': 0.7683556797647378, 'bagging_fraction': 0.7236378135629434, 'bagging_freq': 6, 'min_child_samples': 79}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:54,842] Finished trial#50 with value: 37.826 with parameters: {'lambda_l1': 0.01875732995303787, 'lambda_l2': 0.006888330584749251, 'num_leaves': 80, 'feature_fraction': 0.4988851331822639, 'bagging_fraction': 0.649808971084255, 'bagging_freq': 5, 'min_child_samples': 60}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:55,861] Finished trial#51 with value: 39.157 with parameters: {'lambda_l1': 0.005605281782707205, 'lambda_l2': 0.048815932985875506, 'num_leaves': 25, 'feature_fraction': 0.5594066795543892, 'bagging_fraction': 0.8802884518651866, 'bagging_freq': 7, 'min_child_samples': 50}. Best is trial#29 with value: 40.121.
# [I 2020-07-15 10:41:56,303] Finished trial#52 with value: 41.084 with parameters: {'lambda_l1': 0.23710187490932277, 'lambda_l2': 7.883036381699286e-07, 'num_leaves': 10, 'feature_fraction': 0.4474503738970141, 'bagging_fraction': 0.6204885473855921, 'bagging_freq': 6, 'min_child_samples': 97}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:41:56,912] Finished trial#53 with value: 39.957 with parameters: {'lambda_l1': 0.37252689459314065, 'lambda_l2': 1.7627827017949108e-07, 'num_leaves': 12, 'feature_fraction': 0.6000701520586551, 'bagging_fraction': 0.6103824833497128, 'bagging_freq': 6, 'min_child_samples': 98}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:41:57,143] Finished trial#54 with value: 38.521 with parameters: {'lambda_l1': 3.048916526554193, 'lambda_l2': 1.6733278873250196e-06, 'num_leaves': 2, 'feature_fraction': 0.43946543888547246, 'bagging_fraction': 0.6587880124264909, 'bagging_freq': 6, 'min_child_samples': 72}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:41:57,736] Finished trial#55 with value: 38.634 with parameters: {'lambda_l1': 0.10698941095364958, 'lambda_l2': 1.897147567280575e-08, 'num_leaves': 41, 'feature_fraction': 0.4609163987767016, 'bagging_fraction': 0.5354493697323114, 'bagging_freq': 4, 'min_child_samples': 87}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:41:58,354] Finished trial#56 with value: 39.451 with parameters: {'lambda_l1': 0.44514562181114614, 'lambda_l2': 7.880725948656873e-08, 'num_leaves': 20, 'feature_fraction': 0.5346985790468217, 'bagging_fraction': 0.5469570877153095, 'bagging_freq': 6, 'min_child_samples': 100}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:41:59,179] Finished trial#57 with value: 38.338 with parameters: {'lambda_l1': 0.04442374060305229, 'lambda_l2': 3.4526119612231145e-05, 'num_leaves': 36, 'feature_fraction': 0.4868387866585056, 'bagging_fraction': 0.7059906216849132, 'bagging_freq': 5, 'min_child_samples': 80}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:41:59,904] Finished trial#58 with value: 38.631 with parameters: {'lambda_l1': 0.9536794804816626, 'lambda_l2': 4.5364549734599335e-06, 'num_leaves': 63, 'feature_fraction': 0.7236016557460854, 'bagging_fraction': 0.48227299903525783, 'bagging_freq': 7, 'min_child_samples': 91}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:00,452] Finished trial#59 with value: 38.855 with parameters: {'lambda_l1': 0.0970731528615842, 'lambda_l2': 8.894678534323595e-07, 'num_leaves': 11, 'feature_fraction': 0.5089395210655114, 'bagging_fraction': 0.770239149607718, 'bagging_freq': 5, 'min_child_samples': 66}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:01,738] Finished trial#60 with value: 38.571 with parameters: {'lambda_l1': 0.011328185580602963, 'lambda_l2': 0.27452467831213107, 'num_leaves': 51, 'feature_fraction': 0.4124220934390179, 'bagging_fraction': 0.9759815064267737, 'bagging_freq': 6, 'min_child_samples': 54}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:01,981] Finished trial#61 with value: 31.899 with parameters: {'lambda_l1': 0.338453587998016, 'lambda_l2': 1.236673532508857e-07, 'num_leaves': 2, 'feature_fraction': 0.5864431380977204, 'bagging_fraction': 0.6055033724154175, 'bagging_freq': 6, 'min_child_samples': 97}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:02,629] Finished trial#62 with value: 40.852 with parameters: {'lambda_l1': 0.1675573025029434, 'lambda_l2': 4.4510361708554626e-08, 'num_leaves': 13, 'feature_fraction': 0.6176294599237343, 'bagging_fraction': 0.5585923448040294, 'bagging_freq': 6, 'min_child_samples': 98}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:04,261] Finished trial#63 with value: 39.647 with parameters: {'lambda_l1': 0.17420942306129397, 'lambda_l2': 4.095268078735184e-08, 'num_leaves': 25, 'feature_fraction': 0.6778134836867888, 'bagging_fraction': 0.4748996863356184, 'bagging_freq': 6, 'min_child_samples': 5}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:05,254] Finished trial#64 with value: 40.186 with parameters: {'lambda_l1': 0.023765583088130468, 'lambda_l2': 4.4483432903277004e-07, 'num_leaves': 16, 'feature_fraction': 0.6310112107927288, 'bagging_fraction': 0.5692450885702627, 'bagging_freq': 6, 'min_child_samples': 74}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:06,213] Finished trial#65 with value: 39.228 with parameters: {'lambda_l1': 0.03083617113039958, 'lambda_l2': 6.961986926361847e-07, 'num_leaves': 20, 'feature_fraction': 0.7029412491094007, 'bagging_fraction': 0.561605911971686, 'bagging_freq': 6, 'min_child_samples': 72}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:07,020] Finished trial#66 with value: 40.342 with parameters: {'lambda_l1': 0.0028112586527159933, 'lambda_l2': 1.2397301292373355e-08, 'num_leaves': 32, 'feature_fraction': 0.6280472322823347, 'bagging_fraction': 0.5076098640337707, 'bagging_freq': 6, 'min_child_samples': 75}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:07,524] Finished trial#67 with value: 39.094 with parameters: {'lambda_l1': 0.0006812337991664271, 'lambda_l2': 1.1188383083111677e-08, 'num_leaves': 9, 'feature_fraction': 0.6428309479787159, 'bagging_fraction': 0.5069011147081337, 'bagging_freq': 6, 'min_child_samples': 74}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:08,257] Finished trial#68 with value: 39.293 with parameters: {'lambda_l1': 0.003052852579851628, 'lambda_l2': 3.254443037302057e-08, 'num_leaves': 29, 'feature_fraction': 0.611805480732779, 'bagging_fraction': 0.5016881295015913, 'bagging_freq': 7, 'min_child_samples': 84}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:09,002] Finished trial#69 with value: 38.249 with parameters: {'lambda_l1': 0.008400439732123796, 'lambda_l2': 7.454808465792337e-08, 'num_leaves': 16, 'feature_fraction': 0.6427204835948166, 'bagging_fraction': 0.4431530973171451, 'bagging_freq': 5, 'min_child_samples': 58}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:09,650] Finished trial#70 with value: 39.099 with parameters: {'lambda_l1': 2.7116523427075083e-05, 'lambda_l2': 1.1336094143871484e-08, 'num_leaves': 39, 'feature_fraction': 0.62854077793587, 'bagging_fraction': 0.40656126157931677, 'bagging_freq': 7, 'min_child_samples': 78}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:10,793] Finished trial#71 with value: 38.165 with parameters: {'lambda_l1': 0.0029262717239043564, 'lambda_l2': 4.888549043347034e-07, 'num_leaves': 33, 'feature_fraction': 0.7551508271532502, 'bagging_fraction': 0.5646542667997615, 'bagging_freq': 6, 'min_child_samples': 69}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:11,078] Finished trial#72 with value: 39.022 with parameters: {'lambda_l1': 0.021057662458905974, 'lambda_l2': 1.1299060140181051e-05, 'num_leaves': 3, 'feature_fraction': 0.6063524492123805, 'bagging_fraction': 0.5244993428967645, 'bagging_freq': 6, 'min_child_samples': 61}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:12,035] Finished trial#73 with value: 38.945 with parameters: {'lambda_l1': 0.00034197944120319866, 'lambda_l2': 0.0005600324234262402, 'num_leaves': 22, 'feature_fraction': 0.6812865340360523, 'bagging_fraction': 0.5963547165570491, 'bagging_freq': 6, 'min_child_samples': 81}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:12,687] Finished trial#74 with value: 38.045 with parameters: {'lambda_l1': 1.107142029962729e-08, 'lambda_l2': 5.097163807717629e-05, 'num_leaves': 55, 'feature_fraction': 0.5575533638881147, 'bagging_fraction': 0.4374511560523774, 'bagging_freq': 5, 'min_child_samples': 75}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:13,673] Finished trial#75 with value: 40.726 with parameters: {'lambda_l1': 0.0010999050624716524, 'lambda_l2': 3.243278265305907e-08, 'num_leaves': 16, 'feature_fraction': 0.8463449413578576, 'bagging_fraction': 0.5517639673347426, 'bagging_freq': 6, 'min_child_samples': 63}. Best is trial#52 with value: 41.084.
# [I 2020-07-15 10:42:14,662] Finished trial#76 with value: 41.159 with parameters: {'lambda_l1': 0.0012400189689565906, 'lambda_l2': 2.255118595193422e-08, 'num_leaves': 14, 'feature_fraction': 0.8481318634915431, 'bagging_fraction': 0.5753557838117546, 'bagging_freq': 6, 'min_child_samples': 63}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:15,995] Finished trial#77 with value: 39.094 with parameters: {'lambda_l1': 0.0006753151640146464, 'lambda_l2': 2.4631169522437784e-08, 'num_leaves': 115, 'feature_fraction': 0.8413869504717927, 'bagging_fraction': 0.5474836303014143, 'bagging_freq': 6, 'min_child_samples': 62}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:16,246] Finished trial#78 with value: 37.266 with parameters: {'lambda_l1': 0.001062590175924525, 'lambda_l2': 4.8096489547032184e-08, 'num_leaves': 2, 'feature_fraction': 0.8892678074254462, 'bagging_fraction': 0.5684668624826508, 'bagging_freq': 5, 'min_child_samples': 67}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:17,292] Finished trial#79 with value: 39.448 with parameters: {'lambda_l1': 0.0002229527026333386, 'lambda_l2': 1.0418276053292069e-08, 'num_leaves': 18, 'feature_fraction': 0.7956297734713221, 'bagging_fraction': 0.6320575341332109, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:17,831] Finished trial#80 with value: 40.339 with parameters: {'lambda_l1': 0.00045153885396190425, 'lambda_l2': 2.8983924610084856e-07, 'num_leaves': 7, 'feature_fraction': 0.8215154556350759, 'bagging_fraction': 0.5921714682591714, 'bagging_freq': 6, 'min_child_samples': 94}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:18,388] Finished trial#81 with value: 40.337 with parameters: {'lambda_l1': 7.983478196331442e-05, 'lambda_l2': 2.1884387648969055e-07, 'num_leaves': 7, 'feature_fraction': 0.8238695929088853, 'bagging_fraction': 0.5505801425480683, 'bagging_freq': 6, 'min_child_samples': 94}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:19,047] Finished trial#82 with value: 40.567 with parameters: {'lambda_l1': 6.637471992363171e-05, 'lambda_l2': 2.349980830321249e-07, 'num_leaves': 9, 'feature_fraction': 0.8580862284099726, 'bagging_fraction': 0.549360367140958, 'bagging_freq': 6, 'min_child_samples': 92}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:19,479] Finished trial#83 with value: 40.049 with parameters: {'lambda_l1': 9.00353553506864e-05, 'lambda_l2': 2.639668343752193e-07, 'num_leaves': 5, 'feature_fraction': 0.8670104513832391, 'bagging_fraction': 0.5903126560992155, 'bagging_freq': 6, 'min_child_samples': 88}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:19,991] Finished trial#84 with value: 39.896 with parameters: {'lambda_l1': 7.784626208652709e-06, 'lambda_l2': 1.4178564835077383e-07, 'num_leaves': 7, 'feature_fraction': 0.8185360021071758, 'bagging_fraction': 0.5479758715572893, 'bagging_freq': 6, 'min_child_samples': 94}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:20,897] Finished trial#85 with value: 39.606 with parameters: {'lambda_l1': 6.746304768153099e-05, 'lambda_l2': 7.480989417954062e-08, 'num_leaves': 27, 'feature_fraction': 0.9148788965496537, 'bagging_fraction': 0.5108350159744984, 'bagging_freq': 6, 'min_child_samples': 100}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:21,574] Finished trial#86 with value: 40.19 with parameters: {'lambda_l1': 3.520449308732224e-05, 'lambda_l2': 4.1808871040785154e-07, 'num_leaves': 10, 'feature_fraction': 0.8542518919759147, 'bagging_fraction': 0.5790587514435593, 'bagging_freq': 6, 'min_child_samples': 93}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:22,246] Finished trial#87 with value: 39.453 with parameters: {'lambda_l1': 4.820552350178035e-06, 'lambda_l2': 2.3761310378434944e-07, 'num_leaves': 8, 'feature_fraction': 0.8676946659243567, 'bagging_fraction': 0.5348824167481586, 'bagging_freq': 6, 'min_child_samples': 94}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:23,195] Finished trial#88 with value: 38.474 with parameters: {'lambda_l1': 2.6827873066351263e-05, 'lambda_l2': 1.0022392657212182e-06, 'num_leaves': 186, 'feature_fraction': 0.8490551913631376, 'bagging_fraction': 0.4927657722431819, 'bagging_freq': 7, 'min_child_samples': 90}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:24,303] Finished trial#89 with value: 38.257 with parameters: {'lambda_l1': 5.6533168901702184e-05, 'lambda_l2': 2.660415619924808e-06, 'num_leaves': 31, 'feature_fraction': 0.8164735309736926, 'bagging_fraction': 0.6203192352654701, 'bagging_freq': 6, 'min_child_samples': 86}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:25,152] Finished trial#90 with value: 40.473 with parameters: {'lambda_l1': 1.0044516763226307e-06, 'lambda_l2': 4.8420279013278425e-08, 'num_leaves': 13, 'feature_fraction': 0.7822501619134896, 'bagging_fraction': 0.6449923224140189, 'bagging_freq': 6, 'min_child_samples': 92}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:25,901] Finished trial#91 with value: 40.416 with parameters: {'lambda_l1': 3.140313294933374e-06, 'lambda_l2': 9.032922290834781e-08, 'num_leaves': 11, 'feature_fraction': 0.7828745065708487, 'bagging_fraction': 0.5824400770712679, 'bagging_freq': 6, 'min_child_samples': 96}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:26,188] Finished trial#92 with value: 38.954 with parameters: {'lambda_l1': 1.2028435679495382e-06, 'lambda_l2': 1.0096731352115615e-07, 'num_leaves': 2, 'feature_fraction': 0.7819180716647869, 'bagging_fraction': 0.6002269136531309, 'bagging_freq': 6, 'min_child_samples': 96}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:27,311] Finished trial#93 with value: 39.011 with parameters: {'lambda_l1': 1.1768441449251873e-07, 'lambda_l2': 4.656452665859157e-08, 'num_leaves': 23, 'feature_fraction': 0.8088234908729026, 'bagging_fraction': 0.6739549182375537, 'bagging_freq': 6, 'min_child_samples': 89}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:28,269] Finished trial#94 with value: 39.645 with parameters: {'lambda_l1': 1.2884412124931388e-06, 'lambda_l2': 1.9430099300155404e-08, 'num_leaves': 12, 'feature_fraction': 0.8777605622359952, 'bagging_fraction': 0.6419305557939561, 'bagging_freq': 6, 'min_child_samples': 99}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:29,352] Finished trial#95 with value: 37.208 with parameters: {'lambda_l1': 2.812278583116996e-07, 'lambda_l2': 2.851432472314819e-08, 'num_leaves': 37, 'feature_fraction': 0.8327579182903924, 'bagging_fraction': 0.6159340039748135, 'bagging_freq': 5, 'min_child_samples': 91}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:30,263] Finished trial#96 with value: 40.545 with parameters: {'lambda_l1': 3.8715926418690736e-07, 'lambda_l2': 1.7727727289658463e-07, 'num_leaves': 15, 'feature_fraction': 0.7816888838464127, 'bagging_fraction': 0.51903358010783, 'bagging_freq': 6, 'min_child_samples': 95}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:31,041] Finished trial#97 with value: 38.268 with parameters: {'lambda_l1': 9.286048086824761e-08, 'lambda_l2': 5.903028835689272e-08, 'num_leaves': 26, 'feature_fraction': 0.785843698940827, 'bagging_fraction': 0.45488384301000767, 'bagging_freq': 7, 'min_child_samples': 96}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:31,894] Finished trial#98 with value: 39.751 with parameters: {'lambda_l1': 5.957943833139728e-07, 'lambda_l2': 1.4955053074832927e-08, 'num_leaves': 43, 'feature_fraction': 0.7453209981537349, 'bagging_fraction': 0.5210804331462272, 'bagging_freq': 6, 'min_child_samples': 92}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:32,734] Finished trial#99 with value: 37.882 with parameters: {'lambda_l1': 3.2227758503860874e-07, 'lambda_l2': 1.384717648026892e-07, 'num_leaves': 15, 'feature_fraction': 0.7675221143666265, 'bagging_fraction': 0.5913229650536835, 'bagging_freq': 5, 'min_child_samples': 98}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:33,988] Finished trial#100 with value: 38.76 with parameters: {'lambda_l1': 0.0004546722390132235, 'lambda_l2': 3.339545431393729e-08, 'num_leaves': 21, 'feature_fraction': 0.9310742183220424, 'bagging_fraction': 0.5321133850958153, 'bagging_freq': 6, 'min_child_samples': 85}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:34,526] Finished trial#101 with value: 40.875 with parameters: {'lambda_l1': 3.1304948300183163e-06, 'lambda_l2': 2.2747673118999293e-07, 'num_leaves': 7, 'feature_fraction': 0.8262174837030256, 'bagging_fraction': 0.5546221025541345, 'bagging_freq': 6, 'min_child_samples': 95}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:34,773] Finished trial#102 with value: 38.805 with parameters: {'lambda_l1': 1.961116492975234e-06, 'lambda_l2': 3.414798722563528e-07, 'num_leaves': 2, 'feature_fraction': 0.797257671357361, 'bagging_fraction': 0.5804676824369057, 'bagging_freq': 6, 'min_child_samples': 96}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:35,686] Finished trial#103 with value: 39.974 with parameters: {'lambda_l1': 3.288009370729502e-06, 'lambda_l2': 7.067397018116358e-07, 'num_leaves': 15, 'feature_fraction': 0.8395453820915193, 'bagging_fraction': 0.5525903242545114, 'bagging_freq': 6, 'min_child_samples': 87}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:36,939] Finished trial#104 with value: 39.455 with parameters: {'lambda_l1': 8.965212878557428e-06, 'lambda_l2': 7.942308100060013e-08, 'num_leaves': 33, 'feature_fraction': 0.8886072489436195, 'bagging_fraction': 0.6439344808110012, 'bagging_freq': 6, 'min_child_samples': 89}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:37,494] Finished trial#105 with value: 39.823 with parameters: {'lambda_l1': 1.0130660197127924e-06, 'lambda_l2': 1.7739839392302102e-07, 'num_leaves': 8, 'feature_fraction': 0.7772725681817696, 'bagging_fraction': 0.5154199609726683, 'bagging_freq': 6, 'min_child_samples': 99}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:38,561] Finished trial#106 with value: 39.451 with parameters: {'lambda_l1': 4.7153452291875745e-07, 'lambda_l2': 9.764575067171779e-08, 'num_leaves': 27, 'feature_fraction': 0.813810656452986, 'bagging_fraction': 0.5602031755680268, 'bagging_freq': 6, 'min_child_samples': 83}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:39,481] Finished trial#107 with value: 39.065 with parameters: {'lambda_l1': 1.2065841182466683e-07, 'lambda_l2': 1.506689814105299e-08, 'num_leaves': 21, 'feature_fraction': 0.756866923386857, 'bagging_fraction': 0.532554099041822, 'bagging_freq': 6, 'min_child_samples': 92}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:40,170] Finished trial#108 with value: 39.126 with parameters: {'lambda_l1': 0.002018791734514068, 'lambda_l2': 4.923385759564967e-08, 'num_leaves': 13, 'feature_fraction': 0.734754269551279, 'bagging_fraction': 0.49574294754694964, 'bagging_freq': 7, 'min_child_samples': 95}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:40,441] Finished trial#109 with value: 38.451 with parameters: {'lambda_l1': 1.5608877023440332e-05, 'lambda_l2': 2.3364987055563704e-08, 'num_leaves': 2, 'feature_fraction': 0.8511057247887094, 'bagging_fraction': 0.6076251539534835, 'bagging_freq': 5, 'min_child_samples': 100}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:41,905] Finished trial#110 with value: 39.309 with parameters: {'lambda_l1': 5.177466995071031e-06, 'lambda_l2': 1.4271935255676746e-07, 'num_leaves': 18, 'feature_fraction': 0.9039180440372069, 'bagging_fraction': 0.578370084442833, 'bagging_freq': 6, 'min_child_samples': 98}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:42,691] Finished trial#111 with value: 40.883 with parameters: {'lambda_l1': 0.00012252099616293837, 'lambda_l2': 2.845081467985206e-07, 'num_leaves': 7, 'feature_fraction': 0.8213228178710222, 'bagging_fraction': 0.548457350662717, 'bagging_freq': 6, 'min_child_samples': 93}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:45,218] Finished trial#112 with value: 40.8 with parameters: {'lambda_l1': 0.0002024498312469939, 'lambda_l2': 1.310547285307698e-06, 'num_leaves': 8, 'feature_fraction': 0.8313036467522479, 'bagging_fraction': 0.5407608439160911, 'bagging_freq': 6, 'min_child_samples': 90}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:46,163] Finished trial#113 with value: 40.688 with parameters: {'lambda_l1': 0.00014220549701771852, 'lambda_l2': 9.889090732705313e-07, 'num_leaves': 12, 'feature_fraction': 0.8347388795062624, 'bagging_fraction': 0.46562364987784943, 'bagging_freq': 6, 'min_child_samples': 90}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:47,150] Finished trial#114 with value: 39.593 with parameters: {'lambda_l1': 0.00021905651290555939, 'lambda_l2': 1.2060169905039607e-06, 'num_leaves': 12, 'feature_fraction': 0.8333337559552296, 'bagging_fraction': 0.5380158314091302, 'bagging_freq': 6, 'min_child_samples': 90}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:47,453] Finished trial#115 with value: 39.11 with parameters: {'lambda_l1': 4.388058689449279e-08, 'lambda_l2': 5.761403039171412e-07, 'num_leaves': 2, 'feature_fraction': 0.8781140982135445, 'bagging_fraction': 0.47254867022792946, 'bagging_freq': 6, 'min_child_samples': 92}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:49,368] Finished trial#116 with value: 40.543 with parameters: {'lambda_l1': 0.00011032082700082141, 'lambda_l2': 2.1971125724666325e-06, 'num_leaves': 24, 'feature_fraction': 0.7896889578828218, 'bagging_fraction': 0.5720861122064632, 'bagging_freq': 6, 'min_child_samples': 19}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:51,097] Finished trial#117 with value: 38.533 with parameters: {'lambda_l1': 0.00013250866754917505, 'lambda_l2': 2.8643969890496243e-06, 'num_leaves': 22, 'feature_fraction': 0.8079345630576237, 'bagging_fraction': 0.5662437441595249, 'bagging_freq': 6, 'min_child_samples': 26}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:52,370] Finished trial#118 with value: 39.617 with parameters: {'lambda_l1': 0.00012804009586377306, 'lambda_l2': 7.518292190799512e-06, 'num_leaves': 17, 'feature_fraction': 0.8605571706185934, 'bagging_fraction': 0.5565349756359617, 'bagging_freq': 6, 'min_child_samples': 88}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:58,069] Finished trial#119 with value: 40.128 with parameters: {'lambda_l1': 3.673882309009717e-05, 'lambda_l2': 1.3553107922492794e-06, 'num_leaves': 28, 'feature_fraction': 0.8447247032068589, 'bagging_fraction': 0.5191853225224617, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:42:59,745] Finished trial#120 with value: 40.137 with parameters: {'lambda_l1': 1.8391666119987237e-05, 'lambda_l2': 2.1062789653707907e-06, 'num_leaves': 6, 'feature_fraction': 0.7896377802602237, 'bagging_fraction': 0.541299346537417, 'bagging_freq': 6, 'min_child_samples': 40}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:01,416] Finished trial#121 with value: 40.631 with parameters: {'lambda_l1': 0.0002988862637886605, 'lambda_l2': 8.11814801047481e-07, 'num_leaves': 11, 'feature_fraction': 0.8046159171738353, 'bagging_fraction': 0.57755464613278, 'bagging_freq': 6, 'min_child_samples': 97}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:02,744] Finished trial#122 with value: 40.626 with parameters: {'lambda_l1': 0.0002956967682710181, 'lambda_l2': 8.582527641125764e-07, 'num_leaves': 15, 'feature_fraction': 0.8322233207408564, 'bagging_fraction': 0.5721139618191938, 'bagging_freq': 6, 'min_child_samples': 35}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:04,628] Finished trial#123 with value: 39.516 with parameters: {'lambda_l1': 0.0003679271208431583, 'lambda_l2': 7.388951424483694e-07, 'num_leaves': 24, 'feature_fraction': 0.8386736024059083, 'bagging_fraction': 0.567028822774438, 'bagging_freq': 6, 'min_child_samples': 36}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:06,232] Finished trial#124 with value: 39.968 with parameters: {'lambda_l1': 0.0002628558092396256, 'lambda_l2': 4.191998493676621e-07, 'num_leaves': 18, 'feature_fraction': 0.801235239146933, 'bagging_fraction': 0.5276503248360924, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:07,126] Finished trial#125 with value: 40.265 with parameters: {'lambda_l1': 0.00010144470201961414, 'lambda_l2': 9.888046923275458e-07, 'num_leaves': 7, 'feature_fraction': 0.870504884769418, 'bagging_fraction': 0.5711336081383532, 'bagging_freq': 6, 'min_child_samples': 5}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:08,440] Finished trial#126 with value: 40.229 with parameters: {'lambda_l1': 0.0001671375158041351, 'lambda_l2': 4.376241097001581e-06, 'num_leaves': 16, 'feature_fraction': 0.828952553103425, 'bagging_fraction': 0.4878771087171162, 'bagging_freq': 5, 'min_child_samples': 28}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:10,789] Finished trial#127 with value: 38.783 with parameters: {'lambda_l1': 0.0008014973226987778, 'lambda_l2': 5.494165898107216e-07, 'num_leaves': 37, 'feature_fraction': 0.8560032504302031, 'bagging_fraction': 0.5551309329399245, 'bagging_freq': 6, 'min_child_samples': 21}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:11,107] Finished trial#128 with value: 39.92 with parameters: {'lambda_l1': 4.907218690982963e-05, 'lambda_l2': 3.3758920093372697e-06, 'num_leaves': 3, 'feature_fraction': 0.8092452738738799, 'bagging_fraction': 0.5434482186302326, 'bagging_freq': 6, 'min_child_samples': 31}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:11,753] Finished trial#129 with value: 39.735 with parameters: {'lambda_l1': 0.0016149145049905852, 'lambda_l2': 1.833510812860679e-06, 'num_leaves': 8, 'feature_fraction': 0.8249040933276294, 'bagging_fraction': 0.46233076275345286, 'bagging_freq': 6, 'min_child_samples': 33}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:13,321] Finished trial#130 with value: 39.726 with parameters: {'lambda_l1': 0.00016420070051555773, 'lambda_l2': 2.020493199978322e-07, 'num_leaves': 24, 'feature_fraction': 0.8464089302524359, 'bagging_fraction': 0.6020168856547818, 'bagging_freq': 6, 'min_child_samples': 24}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:14,151] Finished trial#131 with value: 39.965 with parameters: {'lambda_l1': 0.00022365515617019932, 'lambda_l2': 3.3919297257371023e-07, 'num_leaves': 12, 'feature_fraction': 0.7728553741609844, 'bagging_fraction': 0.628119613267183, 'bagging_freq': 6, 'min_child_samples': 97}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:15,308] Finished trial#132 with value: 37.874 with parameters: {'lambda_l1': 0.00010227688149149512, 'lambda_l2': 9.416256833170972e-07, 'num_leaves': 135, 'feature_fraction': 0.8025888933129239, 'bagging_fraction': 0.5751876254756385, 'bagging_freq': 6, 'min_child_samples': 93}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:16,176] Finished trial#133 with value: 39.588 with parameters: {'lambda_l1': 0.0012184789983039563, 'lambda_l2': 2.8185129729749893e-07, 'num_leaves': 14, 'feature_fraction': 0.7509810148201312, 'bagging_fraction': 0.5948918075466312, 'bagging_freq': 6, 'min_child_samples': 100}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:17,360] Finished trial#134 with value: 39.309 with parameters: {'lambda_l1': 6.058296986104845e-07, 'lambda_l2': 1.7148072569685587e-07, 'num_leaves': 251, 'feature_fraction': 0.7911445874844941, 'bagging_fraction': 0.6149604329686627, 'bagging_freq': 6, 'min_child_samples': 86}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:18,904] Finished trial#135 with value: 39.387 with parameters: {'lambda_l1': 0.0005130585609309554, 'lambda_l2': 1.4496940753612384e-06, 'num_leaves': 29, 'feature_fraction': 0.8172422310336438, 'bagging_fraction': 0.5854571213047857, 'bagging_freq': 6, 'min_child_samples': 49}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:20,079] Finished trial#136 with value: 38.262 with parameters: {'lambda_l1': 1.8048606572363498e-07, 'lambda_l2': 5.965330709424509e-07, 'num_leaves': 20, 'feature_fraction': 0.8585271515113465, 'bagging_fraction': 0.5546281062981824, 'bagging_freq': 6, 'min_child_samples': 90}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:20,842] Finished trial#137 with value: 40.265 with parameters: {'lambda_l1': 5.401975348485523e-05, 'lambda_l2': 1.1500044244523061e-07, 'num_leaves': 11, 'feature_fraction': 0.8325941923712119, 'bagging_fraction': 0.5020822957159983, 'bagging_freq': 6, 'min_child_samples': 44}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:21,097] Finished trial#138 with value: 38.297 with parameters: {'lambda_l1': 0.0002645351562463796, 'lambda_l2': 5.703507073091054e-08, 'num_leaves': 2, 'feature_fraction': 0.7649458993342488, 'bagging_fraction': 0.6686706941268682, 'bagging_freq': 6, 'min_child_samples': 95}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:21,612] Finished trial#139 with value: 39.823 with parameters: {'lambda_l1': 0.0006974767374016857, 'lambda_l2': 3.7490791948393203e-07, 'num_leaves': 6, 'feature_fraction': 0.8700341776234477, 'bagging_fraction': 0.5249632661900353, 'bagging_freq': 6, 'min_child_samples': 98}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:22,393] Finished trial#140 with value: 39.663 with parameters: {'lambda_l1': 7.478704020822138e-05, 'lambda_l2': 3.1849768598601284e-08, 'num_leaves': 15, 'feature_fraction': 0.7124083735283452, 'bagging_fraction': 0.5415932078559028, 'bagging_freq': 7, 'min_child_samples': 92}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:23,011] Finished trial#141 with value: 39.665 with parameters: {'lambda_l1': 1.60914184177317e-06, 'lambda_l2': 7.592328854013376e-08, 'num_leaves': 10, 'feature_fraction': 0.7802636070037978, 'bagging_fraction': 0.41762726541262474, 'bagging_freq': 6, 'min_child_samples': 96}. Best is trial#76 with value: 41.159.
# [I 2020-07-15 10:43:24,047] Finished trial#142 with value: 39.002 with parameters: {'lambda_l1': 0.0003663582971772618, 'lambda_l2': 1.0783857587956326e-07, 'num_leaves': 22, 'feature_fraction': 0.7878308912723633, 'bagging_fraction': 0.5835842204334997, 'bagging_freq': 6, 'min_child_samples': 94}. Best is trial#76 with value: 41.159.
# ...
# [I 2020-07-15 11:38:37,350] Finished trial#954 with value: 36.434 with parameters: {'lambda_l1': 0.6808098119388595, 'lambda_l2': 0.0007935739931476698, 'num_leaves': 91, 'feature_fraction': 0.7531944351327752, 'bagging_fraction': 0.9770901618593969, 'bagging_freq': 7, 'min_child_samples': 55}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:40,300] Finished trial#955 with value: 35.718 with parameters: {'lambda_l1': 0.05152009869418293, 'lambda_l2': 7.28428472245837e-05, 'num_leaves': 59, 'feature_fraction': 0.7188751944502481, 'bagging_fraction': 0.9529702926554354, 'bagging_freq': 6, 'min_child_samples': 51}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:41,997] Finished trial#956 with value: 35.951 with parameters: {'lambda_l1': 2.3195886188571958e-07, 'lambda_l2': 0.00225565484861641, 'num_leaves': 72, 'feature_fraction': 0.5088464422164041, 'bagging_fraction': 0.9336638070968568, 'bagging_freq': 7, 'min_child_samples': 63}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:44,036] Finished trial#957 with value: 34.786 with parameters: {'lambda_l1': 0.09198224184647488, 'lambda_l2': 0.00021332059988794457, 'num_leaves': 51, 'feature_fraction': 0.7370840636042602, 'bagging_fraction': 0.6684351695451705, 'bagging_freq': 7, 'min_child_samples': 53}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:45,506] Finished trial#958 with value: 35.086 with parameters: {'lambda_l1': 0.1641006136903687, 'lambda_l2': 0.0005599235524936172, 'num_leaves': 65, 'feature_fraction': 0.7073579572296775, 'bagging_fraction': 0.5185760525029078, 'bagging_freq': 7, 'min_child_samples': 58}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:46,266] Finished trial#959 with value: 35.819 with parameters: {'lambda_l1': 1.2196514404954943e-07, 'lambda_l2': 0.0003206823656642834, 'num_leaves': 74, 'feature_fraction': 0.48787096112955497, 'bagging_fraction': 0.47121786451971004, 'bagging_freq': 7, 'min_child_samples': 89}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:48,481] Finished trial#960 with value: 36.096 with parameters: {'lambda_l1': 0.43779862640657347, 'lambda_l2': 0.004435635513855141, 'num_leaves': 99, 'feature_fraction': 0.6891071021139294, 'bagging_fraction': 0.967917713858359, 'bagging_freq': 7, 'min_child_samples': 72}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:51,190] Finished trial#961 with value: 36.242 with parameters: {'lambda_l1': 0.2542838924724191, 'lambda_l2': 0.0010992222602821053, 'num_leaves': 86, 'feature_fraction': 0.7444852492216002, 'bagging_fraction': 0.9869138155611765, 'bagging_freq': 6, 'min_child_samples': 61}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:53,333] Finished trial#962 with value: 36.387 with parameters: {'lambda_l1': 1.4124748785820693, 'lambda_l2': 0.00015662581777181012, 'num_leaves': 38, 'feature_fraction': 0.7575235389225856, 'bagging_fraction': 0.9534666829313915, 'bagging_freq': 5, 'min_child_samples': 56}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:56,263] Finished trial#963 with value: 36.479 with parameters: {'lambda_l1': 4.0900399249842214e-07, 'lambda_l2': 0.00041622534822224845, 'num_leaves': 60, 'feature_fraction': 0.712107167786691, 'bagging_fraction': 0.9403063065365076, 'bagging_freq': 7, 'min_child_samples': 50}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:38:58,505] Finished trial#964 with value: 36.829 with parameters: {'lambda_l1': 0.9419045314259085, 'lambda_l2': 0.0015861676906924384, 'num_leaves': 78, 'feature_fraction': 0.702258778250838, 'bagging_fraction': 0.9186407924223647, 'bagging_freq': 7, 'min_child_samples': 55}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:02,039] Finished trial#965 with value: 36.166 with parameters: {'lambda_l1': 0.13495771506664248, 'lambda_l2': 0.0002542653968086045, 'num_leaves': 54, 'feature_fraction': 0.8844381012823191, 'bagging_fraction': 0.9694076994487036, 'bagging_freq': 7, 'min_child_samples': 52}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:05,026] Finished trial#966 with value: 35.875 with parameters: {'lambda_l1': 5.437776219777735e-08, 'lambda_l2': 0.003014295165299231, 'num_leaves': 68, 'feature_fraction': 0.7258449455707527, 'bagging_fraction': 0.9865371492764115, 'bagging_freq': 6, 'min_child_samples': 58}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:07,563] Finished trial#967 with value: 35.889 with parameters: {'lambda_l1': 0.06943232225039471, 'lambda_l2': 0.00010083457714520026, 'num_leaves': 44, 'feature_fraction': 0.6667661615046069, 'bagging_fraction': 0.9597617959399708, 'bagging_freq': 7, 'min_child_samples': 54}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:09,628] Finished trial#968 with value: 36.258 with parameters: {'lambda_l1': 1.959116126901433e-06, 'lambda_l2': 0.0008160597761419554, 'num_leaves': 62, 'feature_fraction': 0.5623521742990516, 'bagging_fraction': 0.9447307319631005, 'bagging_freq': 7, 'min_child_samples': 60}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:11,390] Finished trial#969 with value: 35.075 with parameters: {'lambda_l1': 0.4032370765437102, 'lambda_l2': 0.0005932072956890239, 'num_leaves': 49, 'feature_fraction': 0.5436347057822604, 'bagging_fraction': 0.6983837175473872, 'bagging_freq': 7, 'min_child_samples': 48}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:12,848] Finished trial#970 with value: 35.561 with parameters: {'lambda_l1': 3.2707519662841795, 'lambda_l2': 0.0001875543274859127, 'num_leaves': 81, 'feature_fraction': 0.5002651597240911, 'bagging_fraction': 0.9781997936588541, 'bagging_freq': 7, 'min_child_samples': 57}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:15,811] Finished trial#971 with value: 36.27 with parameters: {'lambda_l1': 0.21847459105465153, 'lambda_l2': 0.00034712369529456294, 'num_leaves': 89, 'feature_fraction': 0.7415362432882033, 'bagging_fraction': 0.9318119716781287, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:17,389] Finished trial#972 with value: 36.138 with parameters: {'lambda_l1': 0.6268815252743439, 'lambda_l2': 0.006548107746527108, 'num_leaves': 72, 'feature_fraction': 0.5255539863202386, 'bagging_fraction': 0.9600373786675688, 'bagging_freq': 7, 'min_child_samples': 83}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:19,461] Finished trial#973 with value: 35.058 with parameters: {'lambda_l1': 2.6970311707789883e-07, 'lambda_l2': 0.0013668103761356584, 'num_leaves': 58, 'feature_fraction': 0.7295094888655581, 'bagging_fraction': 0.7232316507788525, 'bagging_freq': 7, 'min_child_samples': 62}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:22,156] Finished trial#974 with value: 36.633 with parameters: {'lambda_l1': 0.09227475176154251, 'lambda_l2': 0.0005478224864837716, 'num_leaves': 68, 'feature_fraction': 0.6855911583341944, 'bagging_fraction': 0.9891217540723333, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:25,174] Finished trial#975 with value: 36.225 with parameters: {'lambda_l1': 0.29042055315767296, 'lambda_l2': 0.002136381770654332, 'num_leaves': 54, 'feature_fraction': 0.7584595579846795, 'bagging_fraction': 0.9707925191382509, 'bagging_freq': 7, 'min_child_samples': 51}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:26,760] Finished trial#976 with value: 35.388 with parameters: {'lambda_l1': 1.5160794045860527e-07, 'lambda_l2': 0.0009306842737137435, 'num_leaves': 78, 'feature_fraction': 0.6521483693331278, 'bagging_fraction': 0.6495248162458794, 'bagging_freq': 6, 'min_child_samples': 67}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:29,518] Finished trial#977 with value: 36.325 with parameters: {'lambda_l1': 1.6497856602174804e-08, 'lambda_l2': 6.854836818756196e-05, 'num_leaves': 64, 'feature_fraction': 0.7154727537869102, 'bagging_fraction': 0.9490604587489712, 'bagging_freq': 7, 'min_child_samples': 60}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:32,304] Finished trial#978 with value: 35.713 with parameters: {'lambda_l1': 2.5932182725588737e-05, 'lambda_l2': 0.0002682334585127833, 'num_leaves': 84, 'feature_fraction': 0.6982943772951827, 'bagging_fraction': 0.9130850635987215, 'bagging_freq': 6, 'min_child_samples': 54}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:34,367] Finished trial#979 with value: 36.322 with parameters: {'lambda_l1': 0.04538002662363589, 'lambda_l2': 0.003768220186921942, 'num_leaves': 75, 'feature_fraction': 0.747208557315597, 'bagging_fraction': 0.87943207019533, 'bagging_freq': 7, 'min_child_samples': 85}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:37,359] Finished trial#980 with value: 36.773 with parameters: {'lambda_l1': 0.16255968402607415, 'lambda_l2': 0.00012049885266667107, 'num_leaves': 91, 'feature_fraction': 0.7285100042198314, 'bagging_fraction': 0.9991167765474028, 'bagging_freq': 7, 'min_child_samples': 58}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:39,155] Finished trial#981 with value: 35.525 with parameters: {'lambda_l1': 0.10386438530501317, 'lambda_l2': 0.00043574546349640556, 'num_leaves': 48, 'feature_fraction': 0.48144379240446683, 'bagging_fraction': 0.9768960765448662, 'bagging_freq': 7, 'min_child_samples': 65}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:43,409] Finished trial#982 with value: 36.048 with parameters: {'lambda_l1': 3.486174138615948e-07, 'lambda_l2': 0.0001592952296597961, 'num_leaves': 58, 'feature_fraction': 0.9914218336857421, 'bagging_fraction': 0.9999069619184819, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:46,446] Finished trial#983 with value: 35.276 with parameters: {'lambda_l1': 1.1204863294686098e-07, 'lambda_l2': 0.0006434007649035149, 'num_leaves': 70, 'feature_fraction': 0.6687714980826709, 'bagging_fraction': 0.960083050782446, 'bagging_freq': 6, 'min_child_samples': 49}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:49,296] Finished trial#984 with value: 35.886 with parameters: {'lambda_l1': 0.3575651302419047, 'lambda_l2': 0.0002802896951273158, 'num_leaves': 101, 'feature_fraction': 0.713131005360786, 'bagging_fraction': 0.9288152324508391, 'bagging_freq': 7, 'min_child_samples': 52}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:51,235] Finished trial#985 with value: 35.808 with parameters: {'lambda_l1': 1.3636830107395682e-05, 'lambda_l2': 0.0011473067675701783, 'num_leaves': 62, 'feature_fraction': 0.6798125548264791, 'bagging_fraction': 0.9477642838367989, 'bagging_freq': 7, 'min_child_samples': 88}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:54,344] Finished trial#986 with value: 36.029 with parameters: {'lambda_l1': 0.18846926046070023, 'lambda_l2': 0.0024598280276125054, 'num_leaves': 51, 'feature_fraction': 0.754625977386051, 'bagging_fraction': 0.9696389844944256, 'bagging_freq': 7, 'min_child_samples': 55}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:56,104] Finished trial#987 with value: 35.945 with parameters: {'lambda_l1': 7.282229108977643e-08, 'lambda_l2': 0.00040484894624137597, 'num_leaves': 39, 'feature_fraction': 0.5113181218057437, 'bagging_fraction': 0.9892617115387837, 'bagging_freq': 7, 'min_child_samples': 63}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:39:58,356] Finished trial#988 with value: 35.673 with parameters: {'lambda_l1': 0.9454091469880858, 'lambda_l2': 5.896225051515015e-05, 'num_leaves': 83, 'feature_fraction': 0.73240282277244, 'bagging_fraction': 0.9399221423491738, 'bagging_freq': 7, 'min_child_samples': 70}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:00,638] Finished trial#989 with value: 36.107 with parameters: {'lambda_l1': 0.5562715908027042, 'lambda_l2': 0.0054117920511364435, 'num_leaves': 95, 'feature_fraction': 0.6005191253977011, 'bagging_fraction': 0.9812377265224972, 'bagging_freq': 7, 'min_child_samples': 58}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:04,043] Finished trial#990 with value: 35.598 with parameters: {'lambda_l1': 6.375459627895599e-07, 'lambda_l2': 0.0001872829637935239, 'num_leaves': 56, 'feature_fraction': 0.7983060166255633, 'bagging_fraction': 0.9586333182321662, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:06,066] Finished trial#991 with value: 34.988 with parameters: {'lambda_l1': 0.06367374741041387, 'lambda_l2': 0.011055318780339439, 'num_leaves': 77, 'feature_fraction': 0.7008703739086382, 'bagging_fraction': 0.9671507261725039, 'bagging_freq': 7, 'min_child_samples': 92}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:08,267] Finished trial#992 with value: 37.817 with parameters: {'lambda_l1': 0.23935815012867506, 'lambda_l2': 0.0016388905682523174, 'num_leaves': 109, 'feature_fraction': 0.53416178852233, 'bagging_fraction': 0.9773894739444129, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:10,530] Finished trial#993 with value: 36.314 with parameters: {'lambda_l1': 0.2598048369851168, 'lambda_l2': 0.0022509616656405692, 'num_leaves': 111, 'feature_fraction': 0.5484112805330734, 'bagging_fraction': 0.9817178613618023, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:12,900] Finished trial#994 with value: 36.72 with parameters: {'lambda_l1': 0.23891764372485239, 'lambda_l2': 0.001728570038961969, 'num_leaves': 106, 'feature_fraction': 0.5751110734010701, 'bagging_fraction': 0.9997413404604474, 'bagging_freq': 6, 'min_child_samples': 59}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:14,395] Finished trial#995 with value: 36.012 with parameters: {'lambda_l1': 0.3893877556964531, 'lambda_l2': 0.002964060465068883, 'num_leaves': 119, 'feature_fraction': 0.5355572570624765, 'bagging_fraction': 0.9881437669036789, 'bagging_freq': 7, 'min_child_samples': 100}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:16,704] Finished trial#996 with value: 35.439 with parameters: {'lambda_l1': 0.14112246448847413, 'lambda_l2': 0.0037421387512778037, 'num_leaves': 115, 'feature_fraction': 0.5508883806660769, 'bagging_fraction': 0.9759529887675721, 'bagging_freq': 7, 'min_child_samples': 54}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:19,098] Finished trial#997 with value: 36.242 with parameters: {'lambda_l1': 0.22909507487240505, 'lambda_l2': 0.0013780841460717184, 'num_leaves': 105, 'feature_fraction': 0.569833148404305, 'bagging_fraction': 0.9997062084737321, 'bagging_freq': 6, 'min_child_samples': 57}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:21,373] Finished trial#998 with value: 36.418 with parameters: {'lambda_l1': 0.12107773158809557, 'lambda_l2': 0.0015633839807380006, 'num_leaves': 109, 'feature_fraction': 0.5327898552082965, 'bagging_fraction': 0.9703484182276728, 'bagging_freq': 7, 'min_child_samples': 54}. Best is trial#791 with value: 38.102.
# [I 2020-07-15 11:40:24,208] Finished trial#999 with value: 36.992 with parameters: {'lambda_l1': 0.48397248527451964, 'lambda_l2': 0.0023997336082346825, 'num_leaves': 119, 'feature_fraction': 0.7210700735873261, 'bagging_fraction': 0.9891532031693153, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial#791 with value: 38.102.
# Accuracy: 38.102
# Parameter: {'lambda_l1': 0.37422203407607046, 'lambda_l2': 0.004151487540770132, 'num_leaves': 96, 'feature_fraction': 0.6983154806051196, 'bagging_fraction': 0.9433270255267205, 'bagging_freq': 7, 'min_child_samples': 50}
